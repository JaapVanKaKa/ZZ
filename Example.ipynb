# %% [markdown]
# <a href="https://colab.research.google.com/github/JaapVanKaKa/ZZ/blob/main/Example.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Only Examples

# %% [markdown]
# # Exploratory Data Analysis and Visualisation

# %%
# Importing the libraries
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns
# %matplotlib inline
import time
import random

# %%
# Importing the dataset
wine = pd.read_csv("https://raw.githubusercontent.com/aniruddhachoudhury/Red-Wine-Quality/master/winequality-red.csv")

# %%
wine.head()
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.4              0.70         0.00             1.9      0.076
# 1            7.8              0.88         0.00             2.6      0.098
# 2            7.8              0.76         0.04             2.3      0.092
# 3           11.2              0.28         0.56             1.9      0.075
# 4            7.4              0.70         0.00             1.9      0.076
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 11.0                  34.0   0.9978  3.51       0.56
# 1                 25.0                  67.0   0.9968  3.20       0.68
# 2                 15.0                  54.0   0.9970  3.26       0.65
# 3                 17.0                  60.0   0.9980  3.16       0.58
# 4                 11.0                  34.0   0.9978  3.51       0.56
#
#    alcohol  quality
# 0      9.4        5
# 1      9.8        5
# 2      9.8        5
# ...

# %%
wine[wine.columns[:11]].describe()
# Out:
#        fixed acidity  volatile acidity  citric acid  residual sugar  \
# count    1599.000000       1599.000000  1599.000000     1599.000000
# mean        8.319637          0.527821     0.270976        2.538806
# std         1.741096          0.179060     0.194801        1.409928
# min         4.600000          0.120000     0.000000        0.900000
# 25%         7.100000          0.390000     0.090000        1.900000
# 50%         7.900000          0.520000     0.260000        2.200000
# 75%         9.200000          0.640000     0.420000        2.600000
# max        15.900000          1.580000     1.000000       15.500000
#
#          chlorides  free sulfur dioxide  total sulfur dioxide      density  \
# count  1599.000000          1599.000000           1599.000000  1599.000000
# mean      0.087467            15.874922             46.467792     0.996747
# std       0.047065            10.460157             32.895324     0.001887
# ...

# %%
corr.head()
# Out:
# quality          1.000000
# alcohol          0.476166
# sulphates        0.251397
# citric acid      0.226373
# fixed acidity    0.124052
# dtype: float64

# %% [markdown]
# #plotting the response variable

# %%
# Load the data into a Pandas DataFrame using read_csv() method.

import pandas as pd

df = pd.read_csv("http://www.ishelp.info/data/insurance.csv")
# Explore the data using various methods such as head(), info(), and describe() to get an idea about the data.

# Check for missing values using isnull() and sum() methods.
print(df.isnull().sum())
# Perform some data visualization using libraries like Matplotlib and Seaborn to understand the relationship between variables.

import seaborn as sns
import matplotlib.pyplot as plt

sns.pairplot(df)
plt.show()
# Out:
# age         0
# sex         0
# bmi         0
# children    0
# smoker      0
# region      0
# charges     0
# dtype: int64

# %%
##  Generates histograms of the numerical columns

# A new Matplotlib figure is created with a size of 15 inches by 12 inches using the figsize parameter.
fig = plt.figure(figsize=(15, 12))

# A title is added to the entire figure using the suptitle function for the entire figure.
plt.suptitle('Histograms of Numerical Columns', fontsize=20)

# A loop is used to iterate over each column in the wine DataFrame.
for i in range(wine.shape[1]):
    # Create a new subplot for the histogram
    plt.subplot(6, 3, i + 1) 
    f = plt.gca()
    # Set the title for the subplot
    f.set_title(wine.columns.values[i]) 
    # Calculate the number of unique values in the column
    # If there are more than 100 unique values, cap the number of bins at 100 
    vals = np.size(wine.iloc[:, i].unique())
    if vals >= 100: 
        vals = 100
    # Create a histogram of the column with the specified number of bins
    plt.hist(wine.iloc[:, i], bins=vals, color='#3F5D7D') 

# Adjust the spacing between the subplots
plt.tight_layout(rect=[0, 0.03, 1, 0.95])

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Load the data into a DataFrame
wine = pd.read_csv("https://raw.githubusercontent.com/aniruddhachoudhury/Red-Wine-Quality/master/winequality-red.csv")

# Calculate the correlation coefficients
corr = wine.corrwith(wine["quality"]).sort_values(ascending=False)

# Set the color palette for the plot
colors = ["#2ECC71" if c >= 0 else "#E74C3C" for c in corr]

# Plot the correlation coefficients as a bar chart
plt.figure(figsize=(15,8))
plt.bar(corr.index, corr.values, color=colors)
plt.title("Correlation with Wine Quality")
plt.xlabel("Features")
plt.ylabel("Correlation Coefficient")
plt.xticks(rotation=45)
plt.grid(axis='y', linestyle='--')
plt.show()

# %%
# Generate colors
colors = sns.color_palette('hls', len(wine.corrwith(wine.quality)))
#  Plot the correlation coefficients of all columns with the "quality" column
wine.corrwith(wine.quality).plot.bar(
    figsize=(15, 8), title="Correlation with quality", fontsize=10,
    rot=45, grid=True, color=colors)
# Out:
# <Axes: title={'center': 'Correlation with quality'}>

# %% [markdown]
# # Pairwise Correlation, corr()

# %% [markdown]
# # Mask Array, Half Heatmap(to hide cells that are not interests) for correlations

# %%
# This code generates a heatmap plot of the correlation matrix computed earlier using the corr() function. 
# A mask array is created which is used to hide the upper triangle of the heatmap.
mask = np.zeros_like(corr, dtype=np.bool)
mask[np.triu_indices_from(mask)] = True

# Set up the matplotlib figure
f, ax = plt.subplots(figsize=(18, 15))

# Generate a custom diverging colormap
cmap = sns.diverging_palette(220, 10, as_cmap=True)

# Draw the heatmap with the mask and correct aspect ratio
sns.heatmap(corr, mask=mask, cmap=cmap, vmax=.3, center=0,
            square=True, linewidths=.5, cbar_kws={"shrink": .5})
# Out:
# <ipython-input-39-507f47ca36eb>:3: DeprecationWarning: `np.bool` is a deprecated alias for the builtin `bool`. To silence this warning, use `bool` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.bool_` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   mask = np.zeros_like(corr, dtype=np.bool)
# <AxesSubplot:>

# %%
from scipy import stats
import statistics as stat

edu_PartialHighSchool = [30000,10000,10000,20000,70000,30000,10000,20000,10000,30000]
edu_HighSchool = [20000,30000,60000,20000,40000,60000,60000]
edu_PartialCollege = [60000,40000,30000,130000,60000,40000]
edu_Bachelors = [40000,20000,90000,120000,60000,130000,20000,100000,80000,100000,120000]
edu_Graduate = [160000,50000,80000,30000,40000,80000,100000,130000,50000,130000]

print('Partial High School: ' + str(int(stat.mean(edu_PartialHighSchool))))
print('High School:         ' + str(int(stat.mean(edu_HighSchool))))
print('Partial College:     ' + str(int(stat.mean(edu_PartialCollege))))
print('Bachelors:           ' + str(int(stat.mean(edu_Bachelors))))
print('Graduate:            ' + str(int(stat.mean(edu_Graduate))))
# the + operator in the given code is used for concatenation or joining of two strings
# Out:
# Partial High School: 24000
# High School:         41428
# Partial College:     60000
# Bachelors:           80000
# Graduate:            85000

# %%
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

plt.figure(figsize=(15, 8))
sns.distplot(edu_PartialHighSchool, label = "Partial High School")
sns.distplot(edu_HighSchool, label = "High School")
sns.distplot(edu_PartialCollege, label = "Partial College")
sns.distplot(edu_Graduate, label = "Graduate")
plt.legend()
